# %% [markdown]
# http://stackoverflow.com/questions/36245039/how-can-i-plot-a-spectrogram-of-a-signal-by-computing-the-power-spectrum-on-binn
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.spectrogram.html

# %%
# %pylab inline --no-import-all
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np

fs = 10e3
N = 1e5
amp = 2 * np.sqrt(2)
noise_power = 0.01 * fs / 2
t = np.arange(N) / float(fs)
mod = 500*np.cos(2*np.pi*0.25*t)
carrier = amp * np.sin(2*np.pi*3e3*t + mod)
noise = np.random.normal(scale=np.sqrt(noise_power), size=t.shape)
noise *= np.exp(-t/5)
x = carrier + noise

plt.figure(figsize=(15,6))
plt.plot(t,x)
plt.title('x')
plt.grid()
plt.show()


f, t, Sxx = signal.spectrogram(x, fs)
plt.figure(figsize=(8,8))
plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

print max(x)
print min(x)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 26.3358199022
# -25.4846609943

# %%
# %pylab inline --no-import-all
from scikits.audiolab import wavread
import matplotlib.pyplot as plt
from scipy import signal

filename = "/Users/kimtaing/Documents/github/MLBD/MLBD/birdsong/BECASSE FILTREe/3h1.1-EQ37B-01.wav"

data, sample_frequency,encoding = wavread(filename)

f, t, Sxx = signal.spectrogram(data[:,0], sample_frequency)

plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

print Sxx.shape
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (129, 295)

# %%
# %pylab inline --no-import-all
from scikits.audiolab import wavread
import matplotlib.pyplot as plt
from scipy import signal

filename = "/Users/kimtaing/Documents/github/MLBD/MLBD/birdsong/NON-BECASSE-FILTREE/a29-EQ37B-01.wav"

data, sample_frequency,encoding = wavread(filename)

f, t, Sxx = signal.spectrogram(data[:,0], sample_frequency)


plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print f.shape, t.shape, Sxx.shape
print f
print t
print Sxx

# %%
print a

# %%
length = waveFile.getnframes()
for i in range(0,length):
    waveData = waveFile.readframes(1)
    data = struct.unpack("<h", waveData)
    print(int(data[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-02bdddaf96c9> in <module>()
# ----> 1 length = waveFile.getnframes()
#       2 for i in range(0,length):
#       3     waveData = waveFile.readframes(1)
#       4     data = struct.unpack("<h", waveData)
#       5     print(int(data[0]))
#
# NameError: name 'waveFile' is not defined
